# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
from src.folder_handler import *
from src.cort_processor import *
from src.cca_processor import *
from src.tdt_support import *
from src.plotter import *
from src.decoders import *
from src.utils import *
import pickle
import scipy as sio
import numpy as np
import matplotlib.pyplot as plt
from  matplotlib.colors import LinearSegmentedColormap
from src.wiener_filter import *
from matplotlib.pyplot import cm
from sklearn.cross_decomposition import CCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
import os
import copy
import pdb

# %%
with open('/home/diya/Documents/rat-fes/data/pickles/rat-annie_5-12_session.pkl', 'rb') as inp: #YOUR PATH HERE
    cp1 = pickle.load(inp)

# %%
h, cp1_vaf, nada, nadax = cp1.decode_angles()
print(np.average(cp1_vaf, 1))
# Out:
# [0.316 0.463 0.161 0.424 0.373 0.073 0.291]

# %%
peaks, nada = cp1.get_gait_indices(angle_number=6)
peaks=peaks[0]
forelimb = cp1.data['angles'][0][:,6]

# %%
which_peak =250
fig, (ax1, ax2) = plt.subplots(2, 1)
for peak in peaks:
    ts = np.arange(forelimb.shape[0])
    ax1.plot(ts, forelimb)
    ax1.scatter(ts[peaks[peak]], forelimb[peaks[peak]], color='red')
    ax2.imshow(cp1.display_frame('/home/diya/Documents/rat-fes/data/rat-annie/5-12/tdt/annie4-220512-152742/live_videos/cam1_annie4-220512-152742_200f-11e100g.avi', 0, peaks[peak]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-cf7fda05b38a> in <module>
#       4     ts = np.arange(forelimb.shape[0])
#       5     ax1.plot(ts, forelimb)
# ----> 6     ax1.scatter(ts[peaks[peak]], forelimb[peaks[peak]], color='red')
#       7     ax2.imshow(cp1.display_frame('/home/diya/Documents/rat-fes/data/rat-annie/5-12/tdt/annie4-220512-152742/live_videos/cam1_annie4-220512-152742_200f-11e100g.avi', 0, peaks[peak]))
#
# IndexError: index 259 is out of bounds for axis 0 with size 257
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
