# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
from src.folder_handler import *
from src.cort_processor import *
from src.cca_processor import *
from src.tdt_support import *
from src.plotter import *
from src.decoders import *
from src.utils import *
import pickle
import scipy as sio
import numpy as np
import matplotlib.pyplot as plt
from  matplotlib.colors import LinearSegmentedColormap
from src.wiener_filter import *
from matplotlib.pyplot import cm
from sklearn.cross_decomposition import CCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
import os
import copy
import pdb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('/home/diya/Documents/rat-fes/data/pickles/3-results-injured-meepolemons1004_meepo_session.pkl', 'rb') as inp: #YOUR PATH HERE
    cp1 = pickle.load(inp)

# %%
h, cp1_vaf, nada, nadax = cp1.decode_angles()
print(np.average(cp1_vaf, 1))
# Out:
# [-0.026 -0.023 -0.032 -0.014  0.005 -0.011 -0.005]

# %%
peaks, nada = cp1.get_gait_indices(angle_number=6)
peaks=peaks[1]
forelimb = cp1.data['angles'][1][:,6]

# %%
fig, ax0 = plt.subplots()
ts = np.arange(forelimb.shape[0])
ax0.plot(ts, forelimb)
ax0.scatter(ts[peaks], forelimb[peaks], color='red')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
which_peak = 11
fig, (ax1, ax2) = plt.subplots(2, 1)
num=peaks[which_peak]
first = np.max((num-50, 0))
last = num + 50

ts = np.arange(first, last)
ax1.plot(ts, forelimb[first:last])
ax1.scatter(num, forelimb[num], color='red')
ax2.imshow(cp1.display_frame('/home/diya/Documents/rat-fes/data/meepo/cam1_meepo1004-221004-154010_200f-11e100g.mp4', 1, peaks[which_peak]))
# Out:
# video_time is: 11.58
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
peaks[1]
# Out:
# 12
