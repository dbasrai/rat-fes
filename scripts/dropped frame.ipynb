# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ts1 = np.load('/home/diya/Documents/rat-fes/data/rat-annie/5-6-22/annie2-220506-135313/live_videos/TIMESTAMPS_cam1_annie2-220506-135313_200f-11e100g.npy')
ts2 = np.load('/home/diya/Documents/rat-fes/data/rat-annie/5-6-22/annie2-220506-135313/live_videos/TIMESTAMPS_cam2_annie2-220506-135313_200f-11e110g.npy')

# %%
droppedframes = -1

if np.size(ts1) > np.size(ts2):
    larger = ts1
    smaller = ts2
else:
    larger = ts2
    smaller = ts1
    
larger = larger[:droppedframes]

deriv = np.gradient(abs(larger-smaller))

# %%
np.argmax(deriv)
# Out:
# 38734

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot(deriv)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig0 = plt.figure()
ax0 = fig0.add_subplot(111)
ax0.plot(abs(ts1-ts2_insert))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
check1 = ts1[36785:36795]
check2 = ts2[36785:36795]

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot(abs(check1-check2))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
insert_num = ts1[36792]

# %%
ts2_insert = np.insert(ts2, 36792, insert_num)

# %%
ts2_insert.shape
# Out:
# (43846,)
